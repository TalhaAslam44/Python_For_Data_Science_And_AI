# %%
# importing liberaries
import numpy as np
import matplotlib.pyplot as plt

# %%
# Importing image from skimage
from skimage import io
photo = io.imread("./Image/image.jpeg")
type(photo)
# Out:
# numpy.ndarray

# %%
# Checking shape of image
photo.shape
# Out:
# (1280, 853, 3)

# %%
plt.imshow
# Out:
# <function matplotlib.pyplot.imshow(X: 'ArrayLike | PIL.Image.Image', cmap: 'str | Colormap | None' = None, norm: 'str | Normalize | None' = None, *, aspect: "Literal['equal', 'auto'] | float | None" = None, interpolation: 'str | None' = None, alpha: 'float | ArrayLike | None' = None, vmin: 'float | None' = None, vmax: 'float | None' = None, origin: "Literal['upper', 'lower'] | None" = None, extent: 'tuple[float, float, float, float] | None' = None, interpolation_stage: "Literal['data', 'rgba'] | None" = None, filternorm: 'bool' = True, filterrad: 'float' = 4.0, resample: 'bool | None' = None, url: 'str | None' = None, data=None, **kwargs) -> 'AxesImage'>

# %%
plt.imshow(photo)

# %%
plt.imshow(photo[::1])

# %%
# For reversing the image
plt.imshow(photo[::-1])

# %%
plt.imshow(photo[::-5])

# %%
plt.imshow(photo[:, ::-1])

# %%
plt.imshow(photo[50:150 , 150 :500])

# %%
plt.imshow(photo[::2, ::2])

# %%
# For taking trignometric function of image
photo 
photo_sin = np.sin(photo)
photo_sin
# Out:
# array([[[-0.822  ,  0.86   , -0.9233 ],
#         [ 0.0354 ,  0.894  , -0.822  ],
#         [-0.822  ,  0.10596,  0.894  ],
#         ...,
#         [ 0.9805 ,  0.4988 , -0.982  ],
#         [ 0.3633 , -0.46   , -0.3713 ],
#         [ 0.3633 , -0.46   , -0.3713 ]],
#
#        [[-0.176  , -0.822  ,  0.7334 ],
#         [ 0.3132 , -0.822  ,  0.9683 ],
#         [-0.63   , -0.176  ,  0.7334 ],
#         ...,
#         [ 0.9805 ,  0.4988 , -0.982  ],
#         [ 0.3633 , -0.46   , -0.3713 ],
#         [-0.588  , -0.9956 ,  0.5806 ]],
#
#        [[-0.9937 , -0.176  , -0.63   ],
#         [ 0.514  ,  0.9683 , -0.444  ],
#         [-0.3877 , -0.444  ,  0.514  ],
#         ...,
#         [-0.9424 ,  0.4988 , -0.3713 ],
#         [ 0.6963 , -0.9956 ,  0.999  ],
#         [ 0.3633 ,  0.33   , -0.46   ]],
#
#        ...,
#
#        [[-0.7393 , -0.5586 ,  0.987  ],
#         [-0.7393 , -0.5586 ,  0.987  ],
#         [-0.9663 ,  0.396  ,  0.6704 ],
#         ...,
# ...

# %%
# rest of function that can be performed on image
print(np.abs(photo))
print(np.absolute(photo))
print(np.sum(photo))
print(np.prod(photo))
print(np.mean(photo))
print(np.std(photo))
print(np.var(photo))
print(np.min(photo))
print(np.max(photo))
print(np.argmin(photo))
print(np.argmax(photo))
# Out:
# [[[ 87  89  86]
#   [ 88  90  87]
#   [ 87  91  90]
#   ...
#   [140 122 118]
#   [141 123 119]
#   [141 123 119]]
#
#  [[ 85  87  84]
#   [ 82  87  83]
#   [ 81  85  84]
#   ...
#   [140 122 118]
#   [141 123 119]
#   [142 124 120]]
#
#  [[ 80  85  81]
#   [ 78  83  79]
#   [ 75  79  78]
#   ...
#   [137 122 119]
#   [139 124 121]
#   [141 126 123]]
#
#  ...
#
#  [[ 62  54  52]
#   [ 62  54  52]
#   [ 61  53  51]
#   ...
#   [ 60  54  54]
#   [ 60  54  54]
#   [ 61  55  55]]
#
#  [[ 62  54  52]
#   [ 62  54  52]
#   [ 61  53  51]
#   ...
#   [ 60  54  54]
#   [ 60  54  54]
#   [ 61  55  55]]
#
#  [[ 62  54  52]
#   [ 62  54  52]
#   [ 61  53  51]
#   ...
#   [ 60  54  54]
#   [ 60  54  54]
#   [ 61  55  55]]]
# [[[ 87  89  86]
#   [ 88  90  87]
#   [ 87  91  90]
#   ...
#   [140 122 118]
#   [141 123 119]
#   [141 123 119]]
#
#  [[ 85  87  84]
#   [ 82  87  83]
#   [ 81  85  84]
#   ...
#   [140 122 118]
#   [141 123 119]
#   [142 124 120]]
#
#  [[ 80  85  81]
#   [ 78  83  79]
# ...

# %%
z = np.array([1,2,3,4,5])

# %%
z >3
# Out:
# array([False, False, False,  True,  True])

# %%
z<4
# Out:
# array([ True,  True,  True, False, False])

# %%
z[z>4]
# Out:
# array([5])

# %% [markdown]
# # determining image pixels and setting condition

# %%
photo_masked = np.where(photo > 100,255,0)

# %%
plt.imshow(photo_masked)

# %%
photo_masked = np.where(photo > 200,255,0)

# %%
plt.imshow(photo_masked)

# %%
a_array = np.array([1,2,3,4,5])
b_array = np.array([6,7,8,9,10])

# %%
a_array + b_array
# Out:
# array([ 7,  9, 11, 13, 15])

# %%
a_array +30
# Out:
# array([31, 32, 33, 34, 35])

# %%
a_array * b_array
# Out:
# array([ 6, 14, 24, 36, 50])

# %%
a_array *10
# Out:
# array([10, 20, 30, 40, 50])

# %%
a_array @ b_array
# Out:
# 130

# %% [markdown]
# # taking transpose

# %%
plt.imshow(photo[:,:,0].T)

# %%
x =np.array([2,1,4,3,5])
np.sort(x)
# Out:
# array([1, 2, 3, 4, 5])
